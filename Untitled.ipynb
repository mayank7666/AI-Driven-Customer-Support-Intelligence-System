# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib as plt

# %%
import seaborn as sns

# %%
df = pd.read_csv("customer_queries_dataset.csv")

# %%
df
# Out:
#                                                 Query            Category
# 0            Hi, mera order abhi tak deliver nahi hua      Delivery Delay
# 1                         Where can I track my order?      Order Tracking
# 2                        I received a damaged product       Product Issue
# 3                          Refund ka process kya hai?      Refund Request
# 4                  Payment failed but amount deducted     Payment Failure
# 5                     Order dispatch hua hai ya nahi?      Order Tracking
# 6                Delivery expected date cross ho gayi      Delivery Delay
# 7                          Product size sahi nahi hai       Product Issue
# 8                           I want to cancel my order      Refund Request
# 9                     Subscription kaise cancel kare?  Subscription Issue
# 10             Order tracking link kaam nahi kar raha      Order Tracking
# 11                     Delivery boy ne call nahi kiya      Delivery Delay
# ...

# %%
df['Category'].value_counts()
# Out:
# Category
# Delivery Delay        9
# Order Tracking        9
# Product Issue         9
# Refund Request        9
# Payment Failure       7
# General Query         6
# Subscription Issue    1
# Name: count, dtype: int64

# %%
new_rows = [
    {"Query": "Subscription renew nahi ho raha", "Category": "Subscription Issue"},
    {"Query": "Auto subscription cancel karna hai", "Category": "Subscription Issue"}
]

df = pd.concat([df, pd.DataFrame(new_rows)], ignore_index=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df['Query'], df['Category'],
    test_size=0.2,
    random_state=42
)

# %%
df = df[df['Category'] != 'Subscription Issue']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df['Query'], df['Category'],
    test_size=0.2,
    stratify=df['Category'],   # 🔥 IMPORTANT
    random_state=42
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    ngram_range=(1,2),   # unigram + bigram
    stop_words='english',
    max_features=500
)

# %%
df = pd.read_csv("customer_queries_dataset.csv")

df = df.dropna()   # important
df = df.reset_index(drop=True)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    df['Query'],
    df['Category'],
    test_size=0.2,
    random_state=42
)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()

X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_vec, y_train)
# Out:
# MultinomialNB()

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_train_vec, y_train)
# Out:
# MultinomialNB()

# %%
import re

def clean_text(text):
    text = text.lower()
    text = re.sub(r'[^a-zA-Z ]', '', text)
    return text

df['Query'] = df['Query'].apply(clean_text)

# %%
vectorizer = TfidfVectorizer(ngram_range=(1,2), max_features=500)

from sklearn.naive_bayes import MultinomialNB
model = MultinomialNB()

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

# Split
X_train, X_test, y_train, y_test = train_test_split(df['Query'], df['Category'], test_size=0.2)

# Convert text → numbers
vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)

# Train model
model = LogisticRegression()
model.fit(X_train_vec, y_train)
# Out:
# LogisticRegression()

# %%
X_test_vec = vectorizer.transform(X_test)
pred = model.predict(X_test_vec)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, pred))
# Out:
# 0.8

# %%
sample = ["Where is my order?", "I want refund", "Payment failed"]

sample_vec = vectorizer.transform(sample)
predictions = model.predict(sample_vec)

for q, p in zip(sample, predictions):
    print(q, "→", p)
# Out:
# Where is my order? → Order Tracking
# I want refund → Refund Request
# Payment failed → Payment Failure

# %% [markdown]
# # Deshboard

# %%
counts = df['Category'].value_counts()
print(counts)
# Out:
# Category
# Delivery Delay        9
# Order Tracking        9
# Product Issue         9
# Refund Request        9
# Payment Failure       7
# General Query         6
# Subscription Issue    1
# Name: count, dtype: int64

# %%
percentage = (counts / len(df)) * 100
print(percentage)
# Out:
# Category
# Delivery Delay        18.0
# Order Tracking        18.0
# Product Issue         18.0
# Refund Request        18.0
# Payment Failure       14.0
# General Query         12.0
# Subscription Issue     2.0
# Name: count, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.figure()
counts.plot(kind='pie', autopct='%1.1f%%')
plt.title("Customer Issues Distribution")
plt.ylabel('')
plt.show()

# %%
plt.figure()
counts.plot(kind='bar')
plt.title("Most Common Customer Issues")
plt.xlabel("Category")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
import pandas as pd

df['Date'] = pd.date_range(start='2025-01-01', periods=len(df))

trend = df.groupby([df['Date'].dt.month, 'Category']).size().unstack()

trend.plot()
plt.title("Monthly Trends")
plt.show()

# %%
import pandas as pd

df = pd.read_csv("customer_queries_dataset.csv")

# %%
X = df['Query']
y = df['Category']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer()
X_vec = vectorizer.fit_transform(X)

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_vec, y)
# Out:
# MultinomialNB()

# %%
model.fit(X_vec, y)
# Out:
# MultinomialNB()

# %%
model.fit(X_vec, y)
# Out:
# MultinomialNB()

# %%
print(X_vec.shape)
print(len(y))
# Out:
# (50, 131)
# 50

# %%
from sklearn.naive_bayes import MultinomialNB

model = MultinomialNB()
model.fit(X_vec, y)

print("Model trained successfully ✅")
# Out:
# Model trained successfully ✅

# %%
sample = ["order kaha hai", "refund chahiye"]

sample_vec = vectorizer.transform(sample)
pred = model.predict(sample_vec)

print(pred)
# Out:
# ['Order Tracking' 'Refund Request']
